# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
data = pd.read_csv("mbti_characters.csv")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 167422 entries, 0 to 167421
# Data columns (total 32 columns):
#  #   Column                           Non-Null Count   Dtype
# ---  ------                           --------------   -----
#  0   id                               167422 non-null  int64
#  1   name                             167422 non-null  object
#  2   cat_id                           167422 non-null  int64
#  3   category                         167422 non-null  object
#  4   sub_cat_id                       167422 non-null  int64
#  5   subcategory                      167422 non-null  object
#  6   four_letter                      167422 non-null  object
#  7   four_letter_total_voted          167422 non-null  int64
#  8   enneagram                        137061 non-null  object
#  9   enneagram_total_voted            167422 non-null  int64
#  10  socionics                        55653 non-null   object
# ...

# %%
data.sample(5)
# Out:
#             id              name  cat_id    category  sub_cat_id  \
# 69534    59823      Texen Raider      11      Gaming        5171
# 157887  243019  Justino Torosián      12  Literature       15459
# 9024    280169        Ben Coogan       2  Television         182
# 75931    72412             Omera       2  Television        5671
# 78481   512908             Yulha      11      Gaming        5850
#
#                                  subcategory four_letter  \
# 69534   Pokémon Rejuvenation (Fan-Made Game)        ESTP
# 157887                          Lo que venga        ISFP
# 9024              Pretty Little Liars (2010)        ESTP
# 75931                 The Mandalorian (2019)        ISFJ
# 78481                             Epic Seven        INFP
#
#         four_letter_total_voted enneagram  enneagram_total_voted  ...  \
# 69534                         1       7w8                      1  ...
# 157887                        1       NaN                      0  ...
# ...

# %%
data.isnull().sum()/data.shape[0]
# Out:
# id                                 0.000000
# name                               0.000000
# cat_id                             0.000000
# category                           0.000000
# sub_cat_id                         0.000000
# subcategory                        0.000000
# four_letter                        0.000000
# four_letter_total_voted            0.000000
# enneagram                          0.181344
# enneagram_total_voted              0.000000
# socionics                          0.667588
# socionics_total_voted              0.000000
# instinctual_variant                0.520666
# instinctual_variant_total_voted    0.000000
# tritype                            0.525170
# tritype_total_voted                0.000000
# temperaments                       0.476891
# temperaments_total_voted           0.000000
# attitudinal_psyche                 0.752285
# attitudinal_psyche_total_voted     0.000000
# big_5_SLOAN                        0.654878
# ...

# %%
columns_to_drop = [
    'id', 'name', 'cat_id', 'sub_cat_id', 'subcategory',
    'four_letter_total_voted', 'enneagram_total_voted', 'socionics_total_voted',
    'instinctual_variant_total_voted', 'tritype_total_voted', 'temperaments_total_voted',
    'attitudinal_psyche_total_voted', 'big_5_SLOAN_total_voted', 'classic_jungian_total_voted',
    'socionics', 'attitudinal_psyche', 'classic_jungian', 'tritype',
    'letter_1', 'letter_1_percentage', 'letter_2', 'letter_2_percentage',
    'letter_3', 'letter_3_percentage', 'letter_4', 'letter_4_percentage'
]

df = data.drop(columns=columns_to_drop)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 167422 entries, 0 to 167421
# Data columns (total 5 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   four_letter          167422 non-null  object
#  1   enneagram            137061 non-null  object
#  2   instinctual_variant  80251 non-null   object
#  3   temperaments         87580 non-null   object
#  4   big_5_SLOAN          57781 non-null   object
# dtypes: object(5)
# memory usage: 6.4+ MB

# %%
df.head()
# Out:
#   four_letter enneagram instinctual_variant            temperaments  \
# 0        INFJ       1w9               so/sp   Phlegmatic [Dominant]
# 1        INTP       6w7               sp/sx  Melancholic [Dominant]
# 2        ENTP       7w8               sp/so     Sanguine-Phlegmatic
# 3        ESTJ       3w4               so/sp     Choleric [Dominant]
# 4        INTP       5w6               sp/sx     Phlegmatic-Choleric
#
#   big_5_SLOAN
# 0       RCOEN
# 1       RLUEI
# 2       SCUAI
# 3       SLOEI
# 4       RCUEI

# %%
df.isnull().sum()/df.shape[0]
# Out:
# four_letter            0.000000
# enneagram              0.181344
# instinctual_variant    0.520666
# temperaments           0.476891
# big_5_SLOAN            0.654878
# dtype: float64

# %%
data['socionics']
# Out:
# 0         EII
# 1         ILI
# 2         ILE
# 3         EIE
# 4         ILE
#          ...
# 167417    SLE
# 167418    NaN
# 167419    NaN
# 167420    NaN
# 167421    NaN
# Name: socionics, Length: 167422, dtype: object
